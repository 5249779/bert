# %% [markdown]
# <a href="https://colab.research.google.com/github/5249779/bert/blob/test/%E2%80%9Cttestt_ipynb%E2%80%9D%E7%9A%84main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch as tc
tc.__version__

# %%
# %cd '/content/drive/My Drive' 
# !pwd
# Out:
# /content/drive/My Drive
# /content/drive/My Drive

# %%
# !mkdir researchHub

# %%
# %cd './researchHub'
# Out:
# /content/drive/MyDrive/researchHub

# %%
# !git clone https://github.com/ChineseGLUE/ChineseGLUE.git
# Out:
# Cloning into 'ChineseGLUE'...
# remote: Enumerating objects: 2053, done.
# remote: Counting objects: 100% (197/197), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 2053 (delta 113), reused 196 (delta 113), pack-reused 1856
# Receiving objects: 100% (2053/2053), 2.35 MiB | 6.04 MiB/s, done.
# Resolving deltas: 100% (1208/1208), done.
# Checking out files: 100% (389/389), done.

# %%
# !pip uninstall tensorflow
# !pip install tensorflow-gpu==1.15
# !apt install --allow-change-held-packages libcudnn7=7.4.1.5-1+cuda10.0
# Out:
# Found existing installation: tensorflow 2.8.2+zzzcolab20220719082949
# Uninstalling tensorflow-2.8.2+zzzcolab20220719082949:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-2.8.2+zzzcolab20220719082949.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)?   ERROR: Operation cancelled by user
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 411.5 MB 7.5 kB/s
# ...
#      |████████████████████████████████| 503 kB 63.0 MB/s
# ...
#      |████████████████████████████████| 50 kB 8.4 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 46.4 MB/s
# ...

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.0'

# %%
print("============查看GPU信息================")
# 查看GPU信息
# !/opt/bin/nvidia-smi
print("==============查看pytorch版本==============")
# 查看pytorch版本
import torch
print(torch.__version__)
print("============查看虚拟机硬盘容量================")
# 查看虚拟机硬盘容量
# !df -lh
print("============查看cpu配置================")
# 查看cpu配置
# !cat /proc/cpuinfo | grep model\ name
print("=============查看内存容量===============")
# 查看内存容量
# !cat /proc/meminfo | grep MemTotal
# Out:
# ============查看GPU信息================
# Tue Sep 20 08:53:44 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python -m pip install --user boto3
# !pip install sacremoses
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 132 kB 7.7 MB/s
# ...
#      |████████████████████████████████| 9.1 MB 57.6 MB/s
# ...
#      |████████████████████████████████| 79 kB 9.4 MB/s
# ...
#      |████████████████████████████████| 140 kB 71.4 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.12 which is incompatible.
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 880 kB 7.3 MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=5f8c8164fa595b80aa47e38a5c1311120a8f6ce3d9e9e7d3a737146e3c91da84
# ...

# %%
# !sh /content/drive/MyDrive/researchHub/ChineseGLUE/baselines/models/bert/run_classifier_lcqmc.sh
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# I0920 11:57:56.382738 139769992738688 tpu_estimator.py:2307] global_step/sec: 1.13517
# INFO:tensorflow:examples/sec: 36.3255
# I0920 11:57:56.383085 139769992738688 tpu_estimator.py:2308] examples/sec: 36.3255
# INFO:tensorflow:global_step/sec: 1.13389
# I0920 11:57:57.264685 139769992738688 tpu_estimator.py:2307] global_step/sec: 1.13389
# INFO:tensorflow:examples/sec: 36.2845
# I0920 11:57:57.265025 139769992738688 tpu_estimator.py:2308] examples/sec: 36.2845
# INFO:tensorflow:global_step/sec: 1.13088
# I0920 11:57:58.148922 139769992738688 tpu_estimator.py:2307] global_step/sec: 1.13088
# INFO:tensorflow:examples/sec: 36.1882
# I0920 11:57:58.149254 139769992738688 tpu_estimator.py:2308] examples/sec: 36.1882
# INFO:tensorflow:global_step/sec: 1.1392
# I0920 11:57:59.026726 139769992738688 tpu_estimator.py:2307] global_step/sec: 1.1392
# INFO:tensorflow:examples/sec: 36.4544
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-9be6659c1502> in <module>
# ----> 1 saver=tf.train.import_meta_graph('lcqmc_output/model.ckpt-10000.meta') #恢复计算图结构
#       2 saver.restore(sess, tf.train.latest_checkpoint("lcqmc_output/")) #恢复所有变量信息
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/training/saver.py in import_meta_graph(meta_graph_or_file, clear_devices, import_scope, **kwargs)
#    1451   return _import_meta_graph_with_return_elements(meta_graph_or_file,
#    1452                                                  clear_devices, import_scope,
# -> 1453                                                  **kwargs)[0]
#    1454
#    1455
#
# ...

# %%
# !cd /content/drive/MyDrive/ChineseGLUE/baselines/models_pytorch/classifier_pytorch
# !sh run_classifier_lcqmc.sh
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# chdir: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# /bin/bash: line 0: cd: /content/drive/MyDrive/ChineseGLUE/baselines/models_pytorch/classifier_pytorch: No such file or directory

# %%
# !git clone https://github.com/CLUEbenchmark/CLUE.git
# Out:
# Cloning into 'CLUE'...
# remote: Enumerating objects: 2822, done.
# remote: Counting objects: 100% (415/415), done.
# remote: Compressing objects: 100% (154/154), done.
# remote: Total 2822 (delta 294), reused 340 (delta 258), pack-reused 2407
# Receiving objects: 100% (2822/2822), 2.46 MiB | 23.54 MiB/s, done.
# Resolving deltas: 100% (1714/1714), done.

# %%
import tensorflow as tf
print(tf.__version__) 
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# 2.8.2
# Found GPU at: /device:GPU:0

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.7 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 35.9 MB/s
# ...
#      |████████████████████████████████| 120 kB 62.9 MB/s
# ...
